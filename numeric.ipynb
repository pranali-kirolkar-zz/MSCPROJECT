# %% [markdown]
# <a href="https://colab.research.google.com/github/pranali-kirolkar/MSCPROJECT/blob/main/numeric.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the python libraries
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
num=LabelEncoder()

# %%
#Sales of Summer clothes Dataset
Dataset = pd.read_csv('/content/Sales Summer Clothes..csv')

# %%
Dataset
# Out:
#        Age   buy clothes  ... any worst experience Rating
# 0    18-25  Occasionally  ...                   No       4
# 1    18-25  Occasionally  ...                  Yes       3
# 2    18-25  Occasionally  ...                  Yes       3
# 3    18-25  Occasionally  ...                  Yes       4
# 4    18-25  Occasionally  ...                   No       5
# ..     ...           ...  ...                  ...     ...
# 197  18-25  Occasionally  ...                   No       4
# 198  18-25     Regularly  ...                   No       4
# 199  18-25     Regularly  ...                   No       4
# 200  18-25  Occasionally  ...                   No       4
# 201  35-50  Occasionally  ...                  Yes       4
#
# [202 rows x 10 columns]

# %%
pd.set_option('display.max_columns',None)

# %%
#length of the data
len(Dataset)
# Out:
# 202

# %%
#check shape of the data
Dataset.shape
# Out:
# (202, 10)

# %%
#preview dataset
Dataset.head(5)
# Out:
#      Age    buyclothes                                               Type  \
# 0  18-25  Occasionally                    Jeans, Women Dress, Ladies Tops
# 1  18-25  Occasionally                                     T-shirt, Jeans
# 2  18-25  Occasionally  T-shirt, Jeans, Women Dress, Casual Dress, Lad...
# 3  18-25  Occasionally                                        Women Dress
# 4  18-25  Occasionally                                        Women Dress
#
#                      Brand     Price                    time_prefer   \
# 0             NIKE, Adidas   500-700                During the sales
# 1        NIKE, Adidas, H&M  700-1000                During the sales
# 2  NIKE, Adidas, H&M, ZARA   200-500                During the sales
# 3                     NIKE   500-700                During the sales
# 4                   Meesho   500-700  Without the sales (Off Season)
#
#   preferpurchasing  compareprices  worstexperience Rating
# ...

# %%
Dataset.tail(10)
# Out:
#        Age   buy clothes  ... any worst experience Rating
# 192  18-25     Regularly  ...                  Yes       3
# 193  25-35     Regularly  ...                  Yes       2
# 194  35-50  Occasionally  ...                   No       4
# 195  25-35  Occasionally  ...                   No       1
# 196  35-50  Occasionally  ...                   No       4
# 197  18-25  Occasionally  ...                   No       4
# 198  18-25     Regularly  ...                   No       4
# 199  18-25     Regularly  ...                   No       4
# 200  18-25  Occasionally  ...                   No       4
# 201  35-50  Occasionally  ...                  Yes       4
#
# [10 rows x 10 columns]

# %%
Dataset.sample(5)
# Out:
#        Age    buyclothes                                    Type  \
# 181  18-25     Regularly                Women Dress, Ladies Tops
# 60   18-25  Occasionally                          T-shirt, Jeans
# 149  18-25  Occasionally                          T-shirt, Jeans
# 133  18-25  Occasionally         Jeans, Women Dress, Ladies Tops
# 124  25-35  Occasionally  Women Dress, Casual Dress, Ladies Tops
#
#                   Brand       Price                    time_prefer   \
# 181                 H&M  1000-above                During the sales
# 60         NIKE, Adidas    700-1000                During the sales
# 149   NIKE, Adidas, H&M    700-1000  Without the sales (Off Season)
# 133  GUCCI, ZARA, LEVIS  1000-above  Without the sales (Off Season)
# 124         ZARA, LEVIS  1000-above  Without the sales (Off Season)
#
#     preferpurchasing  compareprices  worstexperience Rating
# 181            Online            YES              No  5 STAR
# ...

# %%
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                202 non-null    object
#  1   buyclothes         202 non-null    object
#  2   Type               202 non-null    object
#  3   Brand              202 non-null    object
#  4   Price              202 non-null    object
#  5   time_prefer        202 non-null    object
#  6   preferpurchasing   202 non-null    object
#  7   compareprices      202 non-null    object
#  8   worstexperience    202 non-null    object
#  9   Rating             202 non-null    object
# dtypes: object(10)
# memory usage: 15.9+ KB

# %%
Dataset.dtypes
# Out:
# Age                     object
# buy clothes             object
# Type                    object
# Brand                   object
# Price                   object
# time_prefer             object
#  prefer purchasing      object
# compare prices          object
# any worst experience    object
# Rating                   int64
# dtype: object

# %%
Dataset.describe(include='all')
# Out:
#           Age buy clothes  ... any worst experience     Rating
# count     202         202  ...                  202  202.000000
# unique      4           2  ...                    2         NaN
# top     18-25   Regularly  ...                   No         NaN
# freq      162         118  ...                  133         NaN
# mean      NaN         NaN  ...                  NaN    4.292079
# std       NaN         NaN  ...                  NaN    0.880319
# min       NaN         NaN  ...                  NaN    1.000000
# 25%       NaN         NaN  ...                  NaN    4.000000
# 50%       NaN         NaN  ...                  NaN    5.000000
# 75%       NaN         NaN  ...                  NaN    5.000000
# max       NaN         NaN  ...                  NaN    5.000000
#
# [11 rows x 10 columns]

# %%
#view columns name
Dataset.columns
# Out:
# Index(['Age', 'buy clothes', 'Type', 'Brand', 'Price ', 'time_prefer ',
#        ' prefer purchasing ', 'compare prices ', 'any worst experience',
#        'Rating '],
#       dtype='object')

# %%
sns.heatmap(Dataset.isnull(),yticklabels=False,cbar=False,cmap='viridis');

# %%
Dataset.sample(10)
# Out:
#        Age   buy clothes  ... any worst experience Rating
# 26   18-25     Regularly  ...                  Yes       5
# 77   25-35     Regularly  ...                  Yes       5
# 16   18-25     Regularly  ...                   No       5
# 177  18-25     Regularly  ...                   No       5
# 11   18-25  Occasionally  ...                   No       4
# 37   18-25  Occasionally  ...                  Yes       5
# 181  18-25     Regularly  ...                   No       3
# 191  18-25     Regularly  ...                   No       4
# 24   18-25  Occasionally  ...                   No       4
# 10   18-25     Regularly  ...                  Yes       5
#
# [10 rows x 10 columns]

# %% [markdown]
# Converting categorical data into integer

# %%
ds['Age']=num.fit_transform(ds['Age']).astype('int')
ds['buy clothes']=num.fit_transform(ds['buy clothes']).astype('int')
ds['Type']=num.fit_transform(ds['Type']).astype('int')
ds['Brand']=num.fit_transform(ds['Brand']).astype('int')
ds['Price ']=num.fit_transform(ds['Price ']).astype('int')
ds['time_prefer ']=num.fit_transform(ds['time_prefer ']).astype('int')
ds[' prefer purchasing ']=num.fit_transform(ds[' prefer purchasing ']).astype('int')
ds['compare prices ']=num.fit_transform(ds['compare prices ']).astype('int')
ds['any worst experience']=num.fit_transform(ds['any worst experience']).astype('int')
ds['Rating ']=num.fit_transform(ds['Rating ']).astype('int')

# %%
ds
# Out:
#      Age  buy clothes  Type  ...  compare prices   any worst experience  Rating
# 0      0            0     8  ...                1                     0        3
# 1      0            0    13  ...                1                     1        2
# 2      0            0    19  ...                1                     1        2
# 3      0            0    25  ...                1                     1        3
# 4      0            0    25  ...                1                     0        4
# ..   ...          ...   ...  ...              ...                   ...      ...
# 197    0            0     0  ...                1                     0        3
# 198    0            1    27  ...                1                     0        3
# 199    0            1    16  ...                1                     0        3
# 200    0            0    13  ...                0                     0        3
# 201    2            0    26  ...                1                     1        3
#
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   202 non-null    int64
#  1   buy clothes           202 non-null    int64
#  2   Type                  202 non-null    int64
#  3   Brand                 202 non-null    int64
#  4   Price                 202 non-null    int64
#  5   time_prefer           202 non-null    int64
#  6    prefer purchasing    202 non-null    int64
#  7   compare prices        202 non-null    int64
#  8   any worst experience  202 non-null    int64
#  9   Rating                202 non-null    int64
# dtypes: int64(10)
# memory usage: 15.9 KB
