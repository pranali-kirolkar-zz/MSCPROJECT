# %% [markdown]
# <a href="https://colab.research.google.com/github/pranali-kirolkar/MSCPROJECT/blob/main/Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
sns.set()

# %%
#Sales of Summer clothes Dataset
Dataset = pd.read_csv('//content/Sales Summer Clothes....csv') 
Dataset
# Out:
#               Timestamp                     Name  ... any worst experience Rating
# 0        04-08-21 19:06                 Bhairavi  ...                   No  4 STAR
# 1        04-08-21 19:11                   Girish  ...                  Yes  3 STAR
# 2        04-08-21 19:17            Mayuri katkar  ...                  Yes  3 STAR
# 3        04-08-21 19:17                 Harshali  ...                  Yes  4 STAR
# 4        04-08-21 19:20  Sadamast Nikita Shivaji  ...                   No  5 STAR
# ..                  ...                      ...  ...                  ...     ...
# 197  4/27/2021 11:00:23                   Rekha   ...                   No  5 STAR
# 198  4/27/2021 11:00:47           Vaishali kokre  ...                   No  5 STAR
# 199  4/27/2021 11:01:10                   Neeta   ...                   No  5 STAR
# 200  4/27/2021 11:01:37                 Sushant   ...                   No  4 STAR
# ...

# %%
Dataset.head()
# Out:
#         Timestamp                     Name  ... any worst experience Rating
# 0  04-08-21 19:06                 Bhairavi  ...                   No  4 STAR
# 1  04-08-21 19:11                   Girish  ...                  Yes  3 STAR
# 2  04-08-21 19:17            Mayuri katkar  ...                  Yes  3 STAR
# 3  04-08-21 19:17                 Harshali  ...                  Yes  4 STAR
# 4  04-08-21 19:20  Sadamast Nikita Shivaji  ...                   No  5 STAR
#
# [5 rows x 12 columns]

# %%
Dataset.tail()
# Out:
#               Timestamp            Name  ... any worst experience Rating
# 197  4/27/2021 11:00:23          Rekha   ...                   No  5 STAR
# 198  4/27/2021 11:00:47  Vaishali kokre  ...                   No  5 STAR
# 199  4/27/2021 11:01:10          Neeta   ...                   No  5 STAR
# 200  4/27/2021 11:01:37        Sushant   ...                   No  4 STAR
# 201  4/27/2021 11:03:00         Suchita  ...                  Yes  1 STAR
#
# [5 rows x 12 columns]

# %%
Dataset.drop('Timestamp',axis=1,inplace=True)

# %%
Dataset.drop('Name', axis=1, inplace=True)

# %%
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   202 non-null    object
#  1   buy clothes           202 non-null    object
#  2   Type of clothes       202 non-null    object
#  3   Brand of clothes      202 non-null    object
#  4   Price of clothes      202 non-null    object
#  5   time_prefer           202 non-null    object
#  6    prefer purchasing    202 non-null    object
#  7   compare prices        202 non-null    object
#  8   any worst experience  202 non-null    object
#  9   Rating                202 non-null    object
# dtypes: object(10)
# memory usage: 15.9+ KB

# %%
#Check the number of rows and columns
rows,columns=Dataset.shape
print('Number of rows: ',rows)
print('Number of columns: ',columns)
# Out:
# Number of rows:  202
# Number of columns:  10

# %%
Dataset.dtypes
# Out:
# Age                     object
# buy clothes             object
# Type of clothes         object
# Brand of clothes        object
# Price of clothes        object
# time_prefer             object
#  prefer purchasing      object
# compare prices          object
# any worst experience    object
# Rating                  object
# dtype: object

# %%
Dataset.describe()
# Out:
#           Age buy clothes  ... any worst experience Rating
# count     202         202  ...                  202     202
# unique      4           2  ...                    2       5
# top     18-25   Regularly  ...                   No  5 STAR
# freq      162         118  ...                  133     140
#
# [4 rows x 10 columns]

# %%
missing=Dataset.isna().sum().sort_values(ascending=False)
missing.plot.bar(figsize=(10,6))
plt.xlabel('Columns with missing values')
plt.ylabel('Count')
plt.show()

# %%
missing
# Out:
# Rating                  0
# any worst experience    0
# compare prices          0
#  prefer purchasing      0
# time_prefer             0
# Price of clothes        0
# Brand of clothes        0
# Type of clothes         0
# buy clothes             0
# Age                     0
# dtype: int64

# %%
Dataset.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 197    False
# 198    False
# 199    False
# 200    False
# 201    False
# Length: 202, dtype: bool

# %%
Dataset['compare prices '].value_counts()
# Out:
# YES    184
# NO      18
# Name: compare prices , dtype: int64

# %%
fig = plt.figure(figsize = (10,7))
Dataset['compare prices '].hist(bins =10);
plt.title("Do you compare prices to make purchase decisions?")
plt.show()

# %%
Dataset[' prefer purchasing '].value_counts()
# Out:
# By them in Store    107
# Online               95
# Name:  prefer purchasing , dtype: int64

# %%
fig = plt.figure(figsize = (10,7));
sns.countplot(data=Dataset , x = ' prefer purchasing ', color = 'Red');
plt.title("Where do you prefer purchasing clothes?")
plt.show()

# %%
Dataset['time_prefer '].value_counts()
# Out:
# During the sales                  154
# Without the sales (Off Season)     48
# Name: time_prefer , dtype: int64

# %%
fig = plt.figure(figsize = (10,7));
sns.countplot(data=Dataset , x = 'time_prefer ', color = 'Red');
plt.title("Which time do you prefer purchasing Clothes?")
plt.show()

# %%
Dataset['Brand of clothes'].value_counts()
# Out:
# NIKE, Adidas                        33
# Adidas, H&M                         23
# H&M                                 20
# NIKE, Adidas, H&M                   11
# NIKE                                10
# Adidas                              10
# NIKE, Adidas, H&M, LEVIS             9
# H&M, ZARA, LEVIS                     7
# NIKE, Adidas, LEVIS                  6
# NIKE, GUCCI, Adidas                  5
# GUCCI, ZARA, LEVIS                   5
# Adidas, H&M, ZARA, LEVIS             5
# NIKE, Adidas, ZARA, LEVIS            5
# ZARA, LEVIS                          4
# NIKE, Adidas, H&M, ZARA, LEVIS       4
# Adidas, H&M, ZARA                    4
# ZARA                                 3
# Adidas, LEVIS                        3
# GUCCI, Adidas, H&M                   3
# NIKE, GUCCI, Adidas, H&M             2
# NIKE, H&M, ZARA, LEVIS               2
# NIKE, GUCCI, Adidas, LEVIS           2
# LEVIS                                2
# GUCCI, H&M, ZARA, LEVIS              2
# ...

# %%
Dataset['Brand of clothes'].nunique()
# Out:
# 45

# %%
Dataset['Type of clothes '].nunique()
# Out:
# 29

# %%
Dataset['Type of clothes '].value_counts().plot(kind='barh',figsize=(15,10))
plt.title("clothes Type")
plt.show()

# %%
Dataset[' prefer purchasing '].nunique()
# Out:
# 2

# %%
Dataset[' prefer purchasing '].value_counts().plot(kind='barh',figsize=(15,10))
plt.title("Where do you prefer purchasing clothes?")
plt.xlim(0,250)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='buy clothes', hue = 'Age',data=Dataset, color = 'red')
plt.title("Age wise buying clothes")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=' prefer purchasing ', hue = 'Age',data=Dataset, color = 'red')
plt.title("Prefer to purchasing clothes")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Price of clothes', hue = 'Age',data=Dataset, color = 'yellow')
plt.title("Price of clothes comparing with age ")
plt.show()

# %%
Dataset.plot(x = "Brand of clothes", y ="Age" ,kind="scatter", figsize = (10,6))
plt.title("Ratings of IT Devices")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
sns.jointplot(data=Dataset, x='Age',y=' prefer purchasing ', kind='scatter');
plt.show()

# %%
Dataset = pd.DataFrame({'Brand of clothes': ['NIKE', 'Adidas',
'NIKE', 'Adidas', 'H&M',
'NIKE', 'Adidas', 'H&M', 'ZARA'],
                   'data': range(9)}, columns=['Brand of clothes', 'data'])
Dataset
# Out:
#   Brand of clothes  data
# 0             NIKE     0
# 1           Adidas     1
# 2             NIKE     2
# 3           Adidas     3
# 4              H&M     4
# 5             NIKE     5
# 6           Adidas     6
# 7              H&M     7
# 8             ZARA     8

# %%
Dataset.groupby('Brand of clothes')

# %%
Dataset.groupby('Brand of clothes').sum()
# Out:
#                   data
# Brand of clothes
# Adidas              10
# H&M                 11
# NIKE                 7
# ZARA                 8
