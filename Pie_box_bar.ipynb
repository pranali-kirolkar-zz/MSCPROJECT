# %% [markdown]
# <a href="https://colab.research.google.com/github/pranali-kirolkar/MSCPROJECT/blob/main/Pie_box_bar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer

# %%
#Sales of Summer clothes Dataset
Dataset = pd.read_csv('//content/Sales Summer Clothes....csv') 
Dataset
# Out:
#               Timestamp                     Name  ... any worst experience Rating
# 0        04-08-21 19:06                 Bhairavi  ...                   No  4 STAR
# 1        04-08-21 19:11                   Girish  ...                  Yes  3 STAR
# 2        04-08-21 19:17            Mayuri katkar  ...                  Yes  3 STAR
# 3        04-08-21 19:17                 Harshali  ...                  Yes  4 STAR
# 4        04-08-21 19:20  Sadamast Nikita Shivaji  ...                   No  5 STAR
# ..                  ...                      ...  ...                  ...     ...
# 197  4/27/2021 11:00:23                   Rekha   ...                   No  5 STAR
# 198  4/27/2021 11:00:47           Vaishali kokre  ...                   No  5 STAR
# 199  4/27/2021 11:01:10                   Neeta   ...                   No  5 STAR
# 200  4/27/2021 11:01:37                 Sushant   ...                   No  4 STAR
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
duplicate=Dataset[Dataset.duplicated()]
duplicate
# Out:
#          Timestamp          Name    Age buy clothes  \
# 33  04-08-21 22:09  Sayali Pawar  25-35   Regularly
# 40   04-09-21 9:05       Swarup   18-25   Regularly
#
#                                      Type of clothes   \
# 33  T-shirt, Jeans, Women Dress, Casual Dress, Lad...
# 40                                     T-shirt, Jeans
#
#              Brand of clothes Price of clothes      time_prefer   \
# 33  NIKE, Adidas, ZARA, LEVIS          500-700  During the sales
# 40        NIKE, Adidas, LEVIS       1000-above  During the sales
#
#     prefer purchasing  compare prices  any worst experience Rating
# 33    By them in Store              NO                   No  5 STAR
# 40    By them in Store             YES                  Yes  5 STAR

# %%
Dataset=Dataset.fillna(method='ffill')
Dataset
# Out:
#               Timestamp                     Name    Age   buy clothes  \
# 0        04-08-21 19:06                 Bhairavi  18-25  Occasionally
# 1        04-08-21 19:11                   Girish  18-25  Occasionally
# 2        04-08-21 19:17            Mayuri katkar  18-25  Occasionally
# 3        04-08-21 19:17                 Harshali  18-25  Occasionally
# 4        04-08-21 19:20  Sadamast Nikita Shivaji  18-25  Occasionally
# ..                  ...                      ...    ...           ...
# 197  4/27/2021 11:00:23                   Rekha   18-25  Occasionally
# 198  4/27/2021 11:00:47           Vaishali kokre  18-25     Regularly
# 199  4/27/2021 11:01:10                   Neeta   18-25     Regularly
# 200  4/27/2021 11:01:37                 Sushant   18-25  Occasionally
# 201  4/27/2021 11:03:00                  Suchita  35-50  Occasionally
#
#                                       Type of clothes   \
# 0                      Jeans, Women Dress, Ladies Tops
# ...

# %%
Dataset.columns
# Out:
# Index(['Timestamp', 'Name', 'Age', 'buy clothes', 'Type of clothes ',
#        'Brand of clothes', 'Price of clothes', 'time_prefer ',
#        ' prefer purchasing ', 'compare prices ', 'any worst experience',
#        'Rating '],
#       dtype='object')

# %%
Dataset['compare prices '].value_counts().plot(kind='pie',autopct='%1.2f%%',figsize=(10,8))
plt.title("Do you compare prices to make purchase decisions?")
plt.show()

# %%
Dataset['any worst experience'].value_counts().plot(kind='pie',autopct='%1.2f%%',figsize=(10,8))
plt.title("Is there any worst experience in clothes sale?")
plt.show()

# %%
Dataset[' prefer purchasing '].value_counts().plot(kind='pie',autopct='%1.2f%%',figsize=(10,8))
plt.title("Where do you prefer purchasing clothes?")
plt.show()

# %%
Dataset['time_prefer '].value_counts().plot(kind='pie',autopct='%1.2f%%',figsize=(10,8))
plt.title("Which time do you prefer purchasing Clothes?")
plt.show()

# %%
Dataset['Rating '].value_counts().plot(kind='pie',autopct='%1.2f%%',figsize=(10,8))
plt.title("Rating")
plt.show()

# %%
Dataset['Price of clothes'].value_counts().plot(kind='pie',autopct='%1.2f%%',figsize=(10,8))
plt.title("Price of the Clothes :")
plt.show()

# %%
Dataset['buy clothes'].value_counts().plot(kind='pie',autopct='%1.2f%%',figsize=(10,8))
plt.title("How often do you buy clothes in the sale?")
plt.show()

# %%
Dataset['Brand of clothes'].value_counts().plot(kind='barh',figsize=(15,18))
plt.title("Which Brand of clothing have you purchased?")
plt.show()

# %%
Dataset['Type of clothes '].value_counts().plot(kind='bar',figsize=(15,8))
plt.title("Which type of clothing have you purchased recently?")
plt.show()

# %%
Dataset['Age'].value_counts().plot(kind='bar',figsize=(15,8))
plt.title("How old are you?")
plt.show()

# %%
Dataset['Price of clothes'].value_counts().plot(kind='bar',figsize=(10,8))
plt.title("Price of the Clothes :")
plt.show()

# %%
df = pd.DataFrame()

# %%
df = pd.DataFrame(np.random.rand(10, 3), columns=["prefer purchasing",
                                                  "compare prices","any worst experience	"])
color = {
        "boxes": "DarkGreen",
        "whiskers": "DarkOrange",
        "medians": "DarkBlue",
        "caps": "Gray",
   }

df.plot.box(figsize=(10,10),color=color)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns=['Brand of clothes', 'buy clothes'])

# %%
df.plot.area(figsize=(10,10));

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns=['Brand of clothes', 'Type of clothes'])

# %%
df.plot.area(figsize=(10,10));

# %%
df = pd.DataFrame(np.random.randn(220, 2), columns=['Age', 'prefer purchasing'])

# %%
df["prefer purchasing"] = df["prefer purchasing"] + np.arange(220)

# %%
df.plot.hexbin(x="Age", y="prefer purchasing", gridsize=20,figsize=(10,10));
